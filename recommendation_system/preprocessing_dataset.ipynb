# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
dataset = pd.read_excel("gym_recommendation_dataset.xlsx")

# %%
dataset.columns
# Out:
# Index(['ID', 'Sex', 'Age', 'Height', 'Weight', 'Hypertension', 'Diabetes',
#        'BMI', 'Level', 'Fitness Goal', 'Fitness Type', 'Exercises',
#        'Equipment', 'Diet', 'Recommendation'],
#       dtype='object')

# %%
dataset.drop(columns=["Fitness Type", "ID"], inplace=True)  # Drop the index column if it exists

# %%
dataset.columns
# Out:
# Index(['Sex', 'Age', 'Height', 'Weight', 'Hypertension', 'Diabetes', 'BMI',
#        'Level', 'Fitness Goal', 'Exercises', 'Equipment', 'Diet',
#        'Recommendation'],
#       dtype='object')

# %%
dataset.head()
# Out:
#     Sex  Age  Height  Weight Hypertension Diabetes    BMI        Level  \
# 0  Male   18    1.68    47.5           No       No  16.83  Underweight
# 1  Male   18    1.68    47.5          Yes       No  16.83  Underweight
# 2  Male   18    1.68    47.5           No      Yes  16.83  Underweight
# 3  Male   18    1.68    47.5          Yes      Yes  16.83  Underweight
# 4  Male   18    1.68    47.5           No       No  16.83  Underweight
#
#   Fitness Goal                                          Exercises  \
# 0  Weight Gain  Squats, deadlifts, bench presses, and overhead...
# 1  Weight Gain  Squats, deadlifts, bench presses, and overhead...
# 2  Weight Gain  Squats, yoga, deadlifts, bench presses, and ov...
# 3  Weight Gain  Squats, yoga, deadlifts, bench presses, and ov...
# 4  Weight Gain  Squats, deadlifts, bench presses, and overhead...
#
#                                            Equipment  \
# 0                             Dumbbells and barbells
# 1  Light athletic shoes, resistance bands, and li...
# 2      Dumbbells, barbells and Blood glucose monitor
# 3  Light athletic shoes, resistance bands, light ...
# 4                             Dumbbells and barbells
#
#                                                 Diet  \
# 0  Vegetables: (Carrots, Sweet Potato, and Lettuc...
# 1  Vegetables: (Tomatoes, Garlic, leafy greens, b...
# 2  Vegetables: (Garlic, Roma Tomatoes, Capers and...
# 3  Vegetables: (Garlic, Roma Tomatoes, Capers, Gr...
# 4  Vegetables: (Carrots, Sweet Potato, Lettuce); ...
#
#                                       Recommendation
# 0  Follow a regular exercise schedule. Adhere to ...
# 1  Follow a regular exercise schedule. Adhere to ...
# 2  Follow a regular exercise schedule. Adhere to ...
# 3  Follow a regular exercise schedule. Adhere to ...
# 4  Follow a regular exercise schedule. Adhere to ...

# %% [markdown]
# We need to do scaling of numerical columns first

# %%
scaler = StandardScaler()
dataset[['Age', 'Height', 'Weight', 'BMI']] = scaler.fit_transform(dataset[['Age', 'Height', 'Weight', 'BMI']])
dataset.head()
# Out:
#     Sex      Age    Height   Weight Hypertension Diabetes       BMI  \
# 0  Male -1.63391 -0.202298 -1.14858           No       No -1.121606
# 1  Male -1.63391 -0.202298 -1.14858          Yes       No -1.121606
# 2  Male -1.63391 -0.202298 -1.14858           No      Yes -1.121606
# 3  Male -1.63391 -0.202298 -1.14858          Yes      Yes -1.121606
# 4  Male -1.63391 -0.202298 -1.14858           No       No -1.121606
#
#          Level Fitness Goal  \
# 0  Underweight  Weight Gain
# 1  Underweight  Weight Gain
# 2  Underweight  Weight Gain
# 3  Underweight  Weight Gain
# 4  Underweight  Weight Gain
#
#                                            Exercises  \
# 0  Squats, deadlifts, bench presses, and overhead...
# 1  Squats, deadlifts, bench presses, and overhead...
# 2  Squats, yoga, deadlifts, bench presses, and ov...
# 3  Squats, yoga, deadlifts, bench presses, and ov...
# 4  Squats, deadlifts, bench presses, and overhead...
#
#                                            Equipment  \
# 0                             Dumbbells and barbells
# 1  Light athletic shoes, resistance bands, and li...
# 2      Dumbbells, barbells and Blood glucose monitor
# 3  Light athletic shoes, resistance bands, light ...
# 4                             Dumbbells and barbells
#
#                                                 Diet  \
# 0  Vegetables: (Carrots, Sweet Potato, and Lettuc...
# 1  Vegetables: (Tomatoes, Garlic, leafy greens, b...
# 2  Vegetables: (Garlic, Roma Tomatoes, Capers and...
# 3  Vegetables: (Garlic, Roma Tomatoes, Capers, Gr...
# 4  Vegetables: (Carrots, Sweet Potato, Lettuce); ...
#
#                                       Recommendation
# 0  Follow a regular exercise schedule. Adhere to ...
# 1  Follow a regular exercise schedule. Adhere to ...
# 2  Follow a regular exercise schedule. Adhere to ...
# 3  Follow a regular exercise schedule. Adhere to ...
# 4  Follow a regular exercise schedule. Adhere to ...

# %% [markdown]
# Now we need to encode the catergorical columns

# %%
label_encode = LabelEncoder()
for col in ['Sex', 'Hypertension', 'Diabetes', 'Level' ,'Fitness Goal']:
    dataset[col] = label_encode.fit_transform(dataset[col])

# %%
dataset.head()
# Out:
#    Sex      Age    Height   Weight  Hypertension  Diabetes       BMI  Level  \
# 0    1 -1.63391 -0.202298 -1.14858             0         0 -1.121606      3
# 1    1 -1.63391 -0.202298 -1.14858             1         0 -1.121606      3
# 2    1 -1.63391 -0.202298 -1.14858             0         1 -1.121606      3
# 3    1 -1.63391 -0.202298 -1.14858             1         1 -1.121606      3
# 4    1 -1.63391 -0.202298 -1.14858             0         0 -1.121606      3
#
#    Fitness Goal                                          Exercises  \
# 0             0  Squats, deadlifts, bench presses, and overhead...
# 1             0  Squats, deadlifts, bench presses, and overhead...
# 2             0  Squats, yoga, deadlifts, bench presses, and ov...
# 3             0  Squats, yoga, deadlifts, bench presses, and ov...
# 4             0  Squats, deadlifts, bench presses, and overhead...
#
#                                            Equipment  \
# 0                             Dumbbells and barbells
# 1  Light athletic shoes, resistance bands, and li...
# 2      Dumbbells, barbells and Blood glucose monitor
# 3  Light athletic shoes, resistance bands, light ...
# 4                             Dumbbells and barbells
#
#                                                 Diet  \
# 0  Vegetables: (Carrots, Sweet Potato, and Lettuc...
# 1  Vegetables: (Tomatoes, Garlic, leafy greens, b...
# 2  Vegetables: (Garlic, Roma Tomatoes, Capers and...
# 3  Vegetables: (Garlic, Roma Tomatoes, Capers, Gr...
# 4  Vegetables: (Carrots, Sweet Potato, Lettuce); ...
#
#                                       Recommendation
# 0  Follow a regular exercise schedule. Adhere to ...
# 1  Follow a regular exercise schedule. Adhere to ...
# 2  Follow a regular exercise schedule. Adhere to ...
# 3  Follow a regular exercise schedule. Adhere to ...
# 4  Follow a regular exercise schedule. Adhere to ...

# %%
dataset.to_csv('encoded_dataset.csv', index=False)

# %%
import joblib
joblib.dump(scaler, 'trained_scaler.pkl')
# Out:
# ['trained_scaler.pkl']
